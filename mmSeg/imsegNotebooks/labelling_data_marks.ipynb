# %% [markdown]
# ## Creating the labelled data for training and evaluation

# %%
# Import libraries
import os
import cv2
import math
import numpy as np
import pandas as pd

# %% [markdown]
# ## Create the label folder and extract the ground truth information

# %%
# Load the ground truth csv file
via_export = pd.read_csv("../MarkupFromVIA/marks_markup/via_export_csv.csv")

# Create the directory for the labelled data
label_path = "prize_papers/all_labels/"

try:
    os.mkdir(label_path)
except OSError:
    print ("Creation of the directory %s failed" % label_path)
else:
    print ("Successfully created the directory %s " % label_path)


# Create the empty arrays
gtruth = []
page = []
regions = []
curname = ""
# Cycle through each instance of a mark
for x in range(via_export.shape[0]):
    
    # Extract the file name and region properties
    data = via_export.iloc[x]
    
    if data.filename[:-4] == curname:
        
        # reg_properties = [x,y,width,height] where x,y are the bottom left co-ordinates
        reg_properties = []
        temp_shape_data = data.region_shape_attributes[1:-1].split(',')

        # Check that the image actually has a reg
        if len(temp_shape_data) < 5:
            continue
        else:
            for y in range(1,5):
                value = temp_shape_data[y].split(':')

                # Take into account the images have been resized and floor the values
                reg_properties.append(math.floor(int(value[1])*factor))

            # Append new region to regions list
            regions.append(reg_properties)
        
        if x == via_export.shape[0]-1:
            page.append(regions)
            gtruth.append(page)
        
    else:
        page.append(regions)
        gtruth.append(page)
        page = []
        regions = []
        temp_name = data.filename.split('.')
        curname = temp_name[0]
        page.append(curname)
        page.append(data.region_count)

        # reg_properties = [x,y,width,height] where x,y are the bottom left co-ordinates
        reg_properties = []
        temp_shape_data = data.region_shape_attributes[1:-1].split(',')

        # Check that the image actually has a reg
        if len(temp_shape_data) < 5:
            continue
        else:
            for y in range(1,5):
                value = temp_shape_data[y].split(':')

                # Take into account the images have been resized and floor the values
                reg_properties.append(math.floor(int(value[1])*factor))

            # Append new region to regions list
            regions.append(reg_properties)
            if x == via_export.shape[0]-1:
                page.append(regions)
                gtruth.append(page)
            
gtruth.pop(0)
# Out:
# Creation of the directory prize_papers/all_labels/ failed
# [[]]

# %%
# Check Groundtruth collected properly

c = 0
ok = True
for page in gtruth:
    print("\nThe filename: " + page[0])
    print("The file should have " + str(page[1]) + " regions")
    print("It has " + str(len(page[2])) + " regions\n")
    
    print(page)
    
    c = c + len(page[2])
    if page[1] != len(page[2]):
        ok = False
    else:
        continue
    
print("The total number of regions is " + str(c))
print("The CSV was processed properly: " + str(ok))
# Out:
# The filename: 94_20_0026
# The file should have 4 regions
# It has 4 regions
#
# ['94_20_0026', 4, [[616, 6103, 336, 182], [611, 6329, 402, 154], [726, 6476, 198, 70], [719, 6259, 180, 70]]]
#
# The filename: 94_20_0027
# The file should have 19 regions
# It has 19 regions
#
# ['94_20_0027', 19, [[644, 704, 187, 171], [881, 875, 237, 171], [649, 1013, 231, 187], [936, 1183, 149, 187], [671, 1381, 220, 176], [969, 1530, 264, 176], [660, 1701, 275, 165], [870, 1888, 187, 154], [622, 2053, 264, 171], [897, 2207, 198, 143], [682, 2361, 187, 171], [655, 3071, 358, 182], [660, 3610, 341, 165], [671, 3803, 352, 165], [710, 4139, 286, 198], [671, 4353, 187, 198], [660, 4827, 198, 215], [682, 5355, 319, 209], [671, 5861, 314, 242]]]
#
# The filename: 94_20_0028
# The file should have 10 regions
# It has 10 regions
#
# ['94_20_0028', 10, [[638, 996, 264, 171], [611, 1216, 286, 149], [578, 1381, 308, 154], [583, 1866, 237, 209], [633, 2680, 171, 242], [594, 3049, 286, 209], [578, 3946, 281, 220], [605, 4452, 275, 242], [589, 5140, 292, 215], [605, 5966, 303, 308]]]
#
# The filename: 94_20_0029
# The file should have 3 regions
# It has 3 regions
#
# ['94_20_0029', 3, [[671, 699, 187, 154], [677, 1150, 286, 187], [666, 1502, 253, 209]]]
#
# The filename: 94_20_0034
# The file should have 5 regions
# It has 5 regions
#
# ['94_20_0034', 5, [[407, 1453, 374, 209], [374, 3484, 468, 215], [534, 3693, 154, 149], [561, 4502, 374, 215], [402, 5806, 352, 215]]]
#
# The filename: 94_20_0035
# The file should have 8 regions
# It has 8 regions
#
# ['94_20_0035', 8, [[842, 831, 286, 198], [787, 2075, 237, 226], [826, 3357, 462, 193], [886, 3555, 352, 143], [737, 3704, 413, 187], [798, 4744, 325, 204], [743, 5135, 275, 149], [721, 5427, 308, 154]]]
#
# The filename: 94_20_0036
# The file should have 4 regions
# It has 4 regions
#
# ['94_20_0036', 4, [[743, 925, 330, 193], [638, 3060, 374, 259], [726, 4144, 319, 303], [655, 5476, 402, 248]]]
#
# The filename: 94_20_0037
# The file should have 4 regions
# It has 4 regions
#
# ['94_20_0037', 4, [[881, 1497, 292, 253], [826, 2669, 457, 270], [815, 4040, 259, 248], [798, 5349, 495, 253]]]
#
# The filename: 94_20_0038
# The file should have 4 regions
# It has 4 regions
#
# ['94_20_0038', 4, [[556, 1304, 215, 297], [550, 2422, 468, 242], [572, 3357, 473, 264], [561, 4761, 479, 204]]]
#
# The filename: 94_20_0060
# The file should have 2 regions
# It has 2 regions
#
# ['94_20_0060', 2, [[690, 1879, 341, 180], [785, 2055, 139, 125]]]
#
# The filename: 94_20_0066
# The file should have 4 regions
# It has 4 regions
#
# ['94_20_0066', 4, [[1240, 1732, 371, 172], [1369, 1901, 128, 106], [1251, 2194, 316, 143], [1343, 2337, 125, 110]]]
#
# The filename: 94_20_0080
# The file should have 37 regions
# It has 37 regions
#
# ['94_20_0080', 37, [[872, 1439, 250, 146], [903, 1588, 173, 77], [856, 1662, 278, 105], [905, 1764, 206, 80], [845, 1844, 190, 107], [936, 1951, 187, 72], [881, 2045, 201, 96], [914, 2141, 198, 88], [864, 2232, 171, 85], [908, 2320, 168, 72], [828, 2391, 190, 110], [933, 2493, 182, 77], [848, 2578, 253, 121], [820, 2697, 248, 102], [853, 2796, 168, 69], [834, 2873, 267, 105], [894, 2977, 179, 66], [817, 3049, 168, 129], [828, 3173, 256, 94], [848, 3280, 193, 91], [870, 3371, 182, 50], [897, 3423, 151, 96], [897, 3514, 220, 72], [889, 3594, 179, 85], [903, 3676, 182, 80], [850, 4012, 297, 201], [856, 4323, 305, 184], [864, 4521, 300, 165], [872, 4766, 248, 146], [848, 4931, 160, 184], [850, 5237, 248, 165], [828, 5570, 297, 149], [853, 5834, 281, 187], [820, 6147, 300, 143], [815, 6456, 283, 132], [823, 6370, 270, 72], [900, 6291, 135, 85]]]
#
# The filename: 94_20_0081
# The file should have 10 regions
# It has 10 regions
#
# ['94_20_0081', 10, [[462, 774, 227, 150], [499, 1266, 172, 172], [499, 1493, 231, 161], [473, 2029, 242, 198], [503, 2341, 183, 169], [492, 2678, 231, 158], [499, 3119, 242, 191], [503, 3486, 213, 172], [481, 3823, 231, 169], [503, 4179, 227, 154]]]
#
# The filename: 94_20_0105
# The file should have 34 regions
# It has 34 regions
#
# ['94_20_0105', 34, [[624, 1669, 249, 176], [660, 1849, 235, 114], [543, 1952, 385, 161], [613, 2128, 312, 136], [690, 2260, 169, 103], [620, 2359, 272, 169], [602, 2528, 194, 121], [653, 2645, 205, 117], [671, 2763, 183, 114], [649, 2891, 213, 125], [620, 3016, 294, 106], [638, 3185, 286, 128], [726, 3339, 187, 143], [631, 3489, 216, 128], [686, 3607, 253, 147], [682, 3783, 257, 139], [726, 3911, 261, 128], [649, 4124, 242, 103], [613, 4296, 279, 114], [734, 4458, 224, 121], [715, 4656, 213, 92], [730, 4850, 132, 125], [741, 5060, 125, 136], [715, 5199, 147, 106], [726, 5316, 183, 110], [715, 5441, 249, 143], [701, 5584, 283, 121], [723, 5705, 231, 158], [697, 5881, 286, 128], [693, 6014, 194, 117], [697, 4388, 128, 66], [745, 4572, 132, 84], [701, 4751, 227, 99], [675, 4972, 224, 125]]]
#
# The filename: 95_32_0017
# The file should have 2 regions
# It has 2 regions
#
# ['95_32_0017', 2, [[1330, 6072, 555, 339], [1371, 7370, 385, 243]]]
#
# The filename: 95_32_0018
# The file should have 4 regions
# It has 4 regions
#
# ['95_32_0018', 4, [[1624, 3405, 276, 240], [1298, 4658, 475, 226], [1325, 5965, 362, 213], [1334, 7014, 425, 258]]]
#
# The filename: 95_32_0019
# The file should have 5 regions
# It has 5 regions
#
# ['95_32_0019', 5, [[1630, 2742, 353, 205], [1576, 3885, 549, 241], [1545, 5024, 353, 241], [1456, 5899, 317, 214], [1532, 7006, 339, 205]]]
#
# The filename: 95_32_0045
# The file should have 1 regions
# It has 1 regions
#
# ['95_32_0045', 1, [[3869, 2324, 445, 344]]]
#
# The filename: 95_32_0051
# The file should have 1 regions
# It has 1 regions
#
# ['95_32_0051', 1, [[3640, 1884, 472, 257]]]
#
# The filename: 95_32_0061
# The file should have 1 regions
# It has 1 regions
#
# ['95_32_0061', 1, [[3342, 2540, 458, 316]]]
#
# The filename: 103_7_0023
# The file should have 5 regions
# It has 5 regions
#
# ['103_7_0023', 5, [[1183, 2490, 406, 227], [1087, 3962, 482, 193], [1218, 4327, 186, 206], [1156, 4987, 310, 234], [1183, 6143, 413, 358]]]
#
# The filename: 103_7_0024
# The file should have 7 regions
# It has 7 regions
#
# ['103_7_0024', 7, [[1080, 1844, 310, 310], [929, 3185, 206, 220], [942, 3735, 385, 206], [1080, 4409, 193, 213], [894, 5469, 557, 248], [1046, 6384, 358, 282], [977, 5125, 399, 227]]]
#
# The filename: 103_7_0025
# The file should have 5 regions
# It has 5 regions
#
# ['103_7_0025', 5, [[1307, 2009, 289, 255], [1190, 2772, 426, 268], [1231, 3811, 255, 213], [1218, 4719, 289, 186], [1218, 5579, 268, 316]]]
#
# The filename: 103_7_0026
# The file should have 9 regions
# It has 9 regions
#
# ['103_7_0026', 9, [[1224, 1809, 358, 241], [1259, 2077, 186, 165], [1039, 2628, 358, 220], [1046, 2848, 268, 138], [1039, 3013, 275, 144], [1052, 3171, 158, 158], [1183, 4189, 385, 234], [1080, 5668, 378, 213], [1149, 6487, 330, 255]]]
#
# The filename: 103_7_0027
# The file should have 3 regions
# It has 3 regions
#
# ['103_7_0027', 3, [[1286, 2153, 543, 220], [1314, 4100, 420, 227], [1348, 5015, 447, 241]]]
#
# The filename: 103_7_0032
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0032', 1, [[2641, 2682, 637, 330]]]
#
# The filename: 103_7_0033
# The file should have 2 regions
# It has 2 regions
#
# ['103_7_0033', 2, [[2668, 2622, 504, 257], [2760, 2998, 243, 197]]]
#
# The filename: 103_7_0035
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0035', 1, [[2673, 2288, 688, 509]]]
#
# The filename: 103_7_0038
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0038', 1, [[2522, 3026, 436, 403]]]
#
# The filename: 103_7_0043
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0043', 1, [[2760, 2888, 458, 403]]]
#
# The filename: 103_7_0045
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0045', 1, [[2590, 3030, 335, 344]]]
#
# The filename: 103_7_0046
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0046', 1, [[2719, 2535, 330, 458]]]
#
# The filename: 103_7_0047
# The file should have 2 regions
# It has 2 regions
#
# ['103_7_0047', 2, [[2577, 2494, 463, 215], [2604, 2742, 348, 303]]]
#
# The filename: 103_7_0048
# The file should have 4 regions
# It has 4 regions
#
# ['103_7_0048', 4, [[2512, 2283, 573, 293], [2590, 2581, 316, 215], [2531, 2856, 422, 316], [2554, 3163, 220, 312]]]
#
# The filename: 103_7_0056
# The file should have 1 regions
# It has 1 regions
#
# ['103_7_0056', 1, [[2407, 2801, 532, 293]]]
#
# The filename: 105_6_0036
# The file should have 2 regions
# It has 2 regions
#
# ['105_6_0036', 2, [[1115, 5872, 423, 204], [1137, 7184, 474, 211]]]
#
# The filename: 105_6_0037
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0037', 0, []]
#
# The filename: 105_6_0038
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0038', 0, []]
#
# The filename: 105_6_0052
# The file should have 2 regions
# It has 2 regions
#
# ['105_6_0052', 2, [[1662, 3741, 530, 219], [1618, 4504, 301, 131]]]
#
# The filename: 105_6_0053
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0053', 0, []]
#
# The filename: 105_6_0054
# The file should have 1 regions
# It has 1 regions
#
# ['105_6_0054', 1, [[1365, 3625, 637, 282]]]
#
# The filename: 105_6_0055
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0055', 0, []]
#
# The filename: 105_6_0056
# The file should have 1 regions
# It has 1 regions
#
# ['105_6_0056', 1, [[1560, 3168, 491, 180]]]
#
# The filename: 105_6_0057
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0057', 0, []]
#
# The filename: 105_6_0064
# The file should have 0 regions
# It has 0 regions
#
# ['105_6_0064', 0, []]
#
# The filename: 105_6_0065
# The file should have 1 regions
# It has 1 regions
#
# ['105_6_0065', 1, [[2439, 2386, 656, 330]]]
#
# The filename: 113_21_0057
# The file should have 1 regions
# It has 1 regions
#
# ['113_21_0057', 1, [[1173, 4284, 386, 226]]]
#
# The filename: 113_21_0058
# The file should have 0 regions
# It has 0 regions
#
# ['113_21_0058', 0, []]
#
# The filename: 113_21_0059
# The file should have 0 regions
# It has 0 regions
#
# ['113_21_0059', 0, []]
#
# The filename: 113_21_0060
# The file should have 1 regions
# It has 1 regions
#
# ['113_21_0060', 1, [[1319, 3774, 437, 270]]]
#
# The filename: 113_21_0061
# The file should have 1 regions
# It has 1 regions
#
# ['113_21_0061', 1, [[1122, 2033, 291, 168]]]
#
# The filename: 113_21_0086
# The file should have 6 regions
# It has 6 regions
#
# ['113_21_0086', 6, [[2347, 1574, 418, 296], [2323, 2041, 432, 258], [2371, 3013, 364, 204], [2362, 3596, 292, 199], [2347, 4125, 398, 209], [2357, 4597, 316, 204]]]
#
# The filename: 113_21_0087
# The file should have 8 regions
# It has 8 regions
#
# ['113_21_0087', 8, [[2405, 1156, 335, 457], [2323, 1720, 267, 330], [2337, 2216, 321, 219], [2352, 2779, 326, 272], [2337, 3455, 345, 219], [2264, 3737, 282, 204], [2425, 3980, 418, 170], [2415, 4786, 199, 262]]]
#
# The filename: 113_21_0088
# The file should have 9 regions
# It has 9 regions
#
# ['113_21_0088', 9, [[2362, 1254, 292, 228], [2303, 1516, 253, 175], [2308, 1720, 219, 160], [2366, 2123, 296, 199], [2444, 2726, 437, 224], [2434, 3042, 403, 190], [2376, 3912, 306, 243], [2391, 4431, 350, 199], [2415, 4640, 326, 175]]]
#
# The filename: 113_21_0089
# The file should have 7 regions
# It has 7 regions
#
# ['113_21_0089', 7, [[2376, 1239, 311, 209], [2386, 1467, 228, 160], [2332, 1808, 457, 243], [2352, 2337, 253, 292], [2274, 2911, 340, 379], [2347, 3586, 413, 204], [2303, 4227, 398, 233]]]
#
# The filename: 113_21_0092
# The file should have 3 regions
# It has 3 regions
#
# ['113_21_0092', 3, [[1326, 2980, 488, 189], [1319, 4357, 452, 255], [1392, 7089, 357, 168]]]
#
# The filename: 113_21_0093
# The file should have 5 regions
# It has 5 regions
#
# ['113_21_0093', 5, [[1319, 2892, 415, 240], [1333, 3949, 474, 277], [1297, 5114, 255, 204], [1224, 6419, 379, 182], [1275, 6630, 204, 146]]]
#
# The filename: 113_21_0094
# The file should have 6 regions
# It has 6 regions
#
# ['113_21_0094', 6, [[1202, 2528, 313, 364], [1253, 3621, 372, 255], [1202, 4794, 386, 211], [1158, 5807, 226, 117], [1151, 5974, 248, 138], [1246, 6280, 474, 219]]]
#
# The filename: 113_21_0095
# The file should have 8 regions
# It has 8 regions
#
# ['113_21_0095', 8, [[1246, 2499, 350, 386], [1275, 3555, 525, 262], [1253, 3847, 131, 87], [1224, 3963, 148, 95], [1319, 4981, 294, 177], [1338, 5165, 209, 102], [1515, 6071, 321, 134], [1503, 6278, 308, 107]]]
#
# The filename: 113_21_0096
# The file should have 6 regions
# It has 6 regions
#
# ['113_21_0096', 6, [[1337, 2642, 239, 145], [1229, 3886, 347, 209], [1256, 4108, 231, 111], [1285, 5309, 364, 180], [1327, 5504, 219, 131], [1283, 6723, 512, 197]]]
#
# The filename: 113_21_0097
# The file should have 5 regions
# It has 5 regions
#
# ['113_21_0097', 5, [[1276, 2519, 283, 305], [1399, 3691, 360, 195], [1443, 3893, 175, 128], [1322, 4822, 470, 197], [1303, 6235, 465, 222]]]
#
# The filename: 113_21_0098
# The file should have 24 regions
# It has 24 regions
#
# ['113_21_0098', 24, [[1460, 2243, 249, 126], [1446, 2406, 286, 133], [1438, 2724, 268, 133], [1414, 2894, 229, 150], [1389, 3091, 293, 153], [1357, 3440, 209, 133], [1404, 3613, 229, 180], [1349, 3807, 165, 148], [1352, 3935, 192, 138], [1342, 4127, 199, 133], [1340, 4457, 308, 204], [1369, 4982, 135, 209], [1340, 5171, 251, 150], [1377, 5329, 158, 96], [1367, 5435, 133, 94], [1322, 5546, 291, 121], [1322, 5863, 209, 138], [1330, 6023, 177, 99], [1330, 6134, 187, 94], [1322, 6575, 254, 118], [1320, 6728, 197, 160], [1322, 6920, 222, 140], [1327, 7097, 288, 126], [1337, 7272, 313, 101]]]
#
# The filename: 113_21_0099
# The file should have 18 regions
# It has 18 regions
#
# ['113_21_0099', 18, [[2000, 2081, 263, 103], [1980, 2221, 276, 150], [1391, 3253, 209, 133], [1379, 3421, 263, 113], [1384, 3743, 180, 138], [1345, 4076, 256, 310], [1362, 4447, 180, 163], [1354, 4625, 195, 148], [1372, 4827, 231, 123], [1384, 5154, 222, 131], [1396, 5324, 263, 148], [1369, 5676, 308, 135], [1349, 6139, 197, 246], [1335, 6496, 263, 175], [1332, 6696, 199, 118], [1342, 6824, 145, 69], [1308, 6920, 340, 116], [1340, 7228, 199, 128]]]
#
# The filename: 113_21_0100
# The file should have 7 regions
# It has 7 regions
#
# ['113_21_0100', 7, [[1209, 1958, 163, 99], [1212, 2064, 133, 59], [1258, 2273, 298, 131], [1293, 2453, 182, 155], [1295, 2650, 143, 108], [1244, 2793, 318, 126], [1226, 2977, 296, 126]]]
#
# The filename: 114_7_0028
# The file should have 7 regions
# It has 7 regions
#
# ['114_7_0028', 7, [[1658, 2328, 233, 130], [1583, 3440, 195, 147], [1676, 3626, 190, 97], [1226, 4417, 272, 214], [1165, 5621, 413, 251], [1062, 6711, 266, 199], [1049, 6966, 162, 117]]]
#
# The filename: 114_7_0078
# The file should have 38 regions
# It has 38 regions
#
# ['114_7_0078', 38, [[1224, 1244, 180, 153], [1192, 1423, 199, 148], [1133, 1596, 251, 138], [1150, 1739, 131, 140], [1130, 1896, 180, 160], [1108, 2029, 239, 150], [1116, 2167, 254, 158], [1103, 2347, 167, 158], [1106, 2497, 244, 118], [1081, 2650, 217, 135], [1052, 2783, 222, 138], [1037, 2935, 217, 148], [1066, 3098, 182, 126], [1059, 3253, 180, 91], [1027, 3347, 271, 165], [1061, 3509, 163, 148], [1059, 3647, 209, 106], [1071, 3758, 209, 148], [1056, 3891, 165, 150], [1042, 4066, 227, 135], [1071, 4186, 175, 133], [1056, 4329, 236, 135], [1056, 4479, 197, 131], [1007, 4625, 219, 128], [1032, 4772, 204, 111], [1039, 4918, 170, 148], [1042, 5093, 145, 111], [1010, 5250, 187, 128], [1022, 5410, 204, 135], [1007, 5578, 175, 106], [1032, 5713, 170, 133], [1000, 5844, 234, 103], [1015, 5974, 197, 150], [1005, 6134, 180, 138], [1020, 6299, 175, 138], [1022, 6447, 170, 113], [1022, 6740, 185, 126], [1010, 6883, 202, 145]]]
#
# The filename: 105_11_0076
# The file should have 15 regions
# It has 15 regions
#
# ['105_11_0076', 15, [[970, 2276, 300, 201], [1035, 2503, 163, 172], [886, 3669, 364, 154], [973, 3847, 140, 119], [851, 3981, 256, 152], [842, 4156, 283, 149], [868, 4290, 172, 128], [909, 4741, 411, 221], [790, 5971, 254, 175], [769, 6155, 210, 146], [772, 6312, 216, 125], [781, 6458, 204, 117], [807, 6601, 230, 137], [898, 7157, 431, 166], [988, 7358, 152, 251]]]
#
# The filename: 105_11_0077
# The file should have 7 regions
# It has 7 regions
#
# ['105_11_0077', 7, [[1309, 1942, 428, 204], [1285, 3221, 355, 165], [1229, 4111, 387, 180], [1197, 4306, 375, 177], [1132, 5231, 369, 151], [1067, 5423, 426, 168], [1312, 6478, 355, 313]]]
#
# The filename: 105_11_0099
# The file should have 1 regions
# It has 1 regions
#
# ['105_11_0099', 1, [[1239, 2163, 638, 388]]]
#
# The filename: 105_11_0100
# The file should have 0 regions
# It has 0 regions
#
# ['105_11_0100', 0, []]
#
# The filename: 105_11_0103
# The file should have 2 regions
# It has 2 regions
#
# ['105_11_0103', 2, [[1497, 2060, 811, 418], [1608, 2425, 466, 816]]]
#
# The filename: 105_11_0104
# The file should have 0 regions
# It has 0 regions
#
# ['105_11_0104', 0, []]
#
# The filename: 105_11_0105
# The file should have 1 regions
# It has 1 regions
#
# ['105_11_0105', 1, [[1328, 2041, 939, 460]]]
#
# The filename: 105_11_0106
# The file should have 0 regions
# It has 0 regions
#
# ['105_11_0106', 0, []]
#
# The filename: 105_11_0117
# The file should have 1 regions
# It has 1 regions
#
# ['105_11_0117', 1, [[1406, 2488, 499, 279]]]
# The total number of regions is 775
# The CSV was processed properly: True

# %%
#Create the GT of the PPs that have no marks

for dirName, subdirList, fileList in os.walk(image_path):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        file_name = fname.split(".")
        #print('\t%s' % file_name[0])
        # Open image
        img = cv2.imread(image_path + file_name[0] + '.jpg', 1)
        img = cv2.rectangle(img, (0,0), (img.shape[1], img.shape[0]), (0,0,0), -1)

        # Save figure
        cv2.imwrite(label_path + file_name[0] + '.png', img)
# Out:
# Found directory: ../SampleSets/

# %% [markdown]
# ## Create the labels

# %%
for page in gtruth:
    filename = page[0] 
    regions = page[2]
    file_dir = "../SampleSets/" + filename + ".jpg"
    
    img = cv2.imread(file_dir)
    img = cv2.rectangle(img, (0,0), (img.shape[1], img.shape[0]), (0,0,0), -1)
    
    for region in regions:
        
        bl = (region[0],region[1])
        tr = (region[0]+region[2], region[1]+region[3])
        
        # Top left, Bottom right corners
        img = cv2.rectangle(img, bl, tr, (0,0,255), -1)
        
    print("Saving " + filename)
    cv2.imwrite(label_path + filename + ".png", img)
# Out:
# Saving 94_20_0026
# Saving 94_20_0027
# Saving 94_20_0028
# Saving 94_20_0029
# Saving 94_20_0034
# Saving 94_20_0035
# Saving 94_20_0036
# Saving 94_20_0037
# Saving 94_20_0038
# Saving 94_20_0060
# Saving 94_20_0066
# Saving 94_20_0080
# Saving 94_20_0081
# Saving 94_20_0105
# Saving 95_32_0017
# Saving 95_32_0018
# Saving 95_32_0019
# Saving 95_32_0045
# Saving 95_32_0051
# Saving 95_32_0061
# Saving 103_7_0023
# Saving 103_7_0024
# Saving 103_7_0025
# Saving 103_7_0026
# Saving 103_7_0027
# Saving 103_7_0032
# Saving 103_7_0033
# Saving 103_7_0035
# Saving 103_7_0038
# Saving 103_7_0043
# Saving 103_7_0045
# Saving 103_7_0046
# Saving 103_7_0047
# Saving 103_7_0048
# Saving 103_7_0056
# Saving 105_6_0036
# Saving 105_6_0037
# Saving 105_6_0038
# Saving 105_6_0052
# Saving 105_6_0053
# Saving 105_6_0054
# Saving 105_6_0055
# Saving 105_6_0056
# Saving 105_6_0057
# Saving 105_6_0064
# Saving 105_6_0065
# Saving 113_21_0057
# Saving 113_21_0058
# Saving 113_21_0059
# Saving 113_21_0060
# Saving 113_21_0061
# Saving 113_21_0086
# Saving 113_21_0087
# Saving 113_21_0088
# Saving 113_21_0089
# Saving 113_21_0092
# Saving 113_21_0093
# Saving 113_21_0094
# Saving 113_21_0095
# Saving 113_21_0096
# Saving 113_21_0097
# Saving 113_21_0098
# Saving 113_21_0099
# Saving 113_21_0100
# Saving 114_7_0028
# Saving 114_7_0029
# Saving 114_7_0030
# Saving 114_7_0031
# Saving 114_7_0036
# Saving 114_7_0037
# Saving 114_7_0038
# Saving 114_7_0041
# Saving 114_7_0042
# Saving 114_7_0043
# Saving 114_7_0044
# Saving 114_7_0069
# Saving 114_7_0070
# Saving 114_7_0071
# Saving 114_7_0075
# Saving 114_7_0076
# Saving 114_7_0077
# Saving 114_7_0078
# Saving 105_11_0076
# Saving 105_11_0077
# Saving 105_11_0099
# Saving 105_11_0100
# Saving 105_11_0103
# Saving 105_11_0104
# Saving 105_11_0105
# Saving 105_11_0106
# Saving 105_11_0117
