# %% [markdown]
# ## Seeing the difference of the projection signature between analysing the whole image vs just the prize paper

# %%
# Import libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

########################
#This section just to get the images that we want (Where the ruler is on the top)

ruler_tb = []
ruler_lr = []

rootDir = '../ResizedSS4/'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        file_name = fname.split(".")
        #print('\t%s' % file_name[0])
        
        bin_sig3 = []
        peaks = []
        p = []
        
        #reading the file
        image = cv2.imread(dirName + '/' + fname)
        
        #Converting to greyscale
        gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        sig = np.sum(gry, axis=1)
        
        #get threshold values
        minV = min(sig)
        
        ran = max(sig) - min(sig)
        ran_threshold = 0.2
        
        #Check for peaks, form binary signal, store pixel values for peak and append to peaks.
        for n in range(len(sig)):
            if sig[n] > minV + ran_threshold*ran:
                bin_sig3.append(5000)
                p.append(n)
            else:
                if n < len(sig) - 3:
                    if sig[n+3] > minV + ran_threshold*ran:
                        bin_sig3.append(5000)
                        p.append(n)
                    else:
                        bin_sig3.append(0)
                        if len(p) != 0:
                            peaks.append(p)
                            p = []
                        else:
                            continue
                else:
                    bin_sig3.append(0)
                    if len(p) != 0:
                        peaks.append(p)
                        p = []
                    else:
                        continue
                                    
        #plt.plot(sig)
        #plt.plot(bin_sig3)
        #plt.show()
        #print(bin_sig3)
        #print(len(peaks))
        
        if len(peaks)!=2:
            ruler_lr.append(file_name[0])
        else:
            data = [file_name[0],peaks]
            ruler_tb.append(data)

##########################
# Out:
# Found directory: ../ResizedSS4/

# %%
##########################
# Prototype code for margin detection

rootDir = '../ResizedSS4/'

# Create the directory for the outputs
path = "../Outputs/Plots/Ruler_Removed_Diff/"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
    
for x in range(len(ruler_tb)):
    
    # Get variables
    peaks = ruler_tb[x][1]
    filename = ruler_tb[x][0]
    
    # Check if the ruler is on the top or the bottom
    if len(ruler_tb[x][1][1]) > len(ruler_tb[x][1][0]):
        index = 1
    else:
        index = 0
        
    first_row = ruler_tb[x][1][index][1]
    last_row = ruler_tb[x][1][index][len(ruler_tb)-1]
    peak = ruler_tb[x][1][index]
    
#    print(peak)
    
    # Edge detection
    img = cv2.imread(rootDir + '/' + filename + '.jpg')
    gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gry,100,200)
    
    # Sum over rows to get a signal as a function of columns
    sig = np.sum(edges[peak], axis=0)
#    print(sig[300])
    
    sig2 = np.sum(edges, axis=0)
        
    # Plotting 
    plt.plot(sig2, label='Whole image')
    plt.plot(sig, label='Paper only')
    plt.ylabel('Sum of pixels across rows')
    plt.xlabel('Column')
    plt.legend()
    plt.title('Sum of pixels across rows as a function of column for ' + filename)
    plt.savefig(path + filename + '.svg')
    plt.show()
# Out:
# Successfully created the directory ../Outputs/Plots/Ruler_Removed_Diff/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-30ff3a1d8805> in <module>
#      50     plt.legend()
#      51     plt.title('Sum of pixels across rows as a function of column for ' + filename)
# ---> 52     plt.savefig(path + filename + '.svg')
#      53     plt.show()
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1200                 detach = True
#    1201
# -> 1202             result = self._print_svg(filename, fh, **kwargs)
#    1203
#    1204             # Detach underlying stream from wrapper so that it remains open in
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/backends/backend_svg.py in _print_svg(self, filename, fh, dpi, bbox_inches_restore, **kwargs)
#    1225             bbox_inches_restore=bbox_inches_restore)
#    1226
# -> 1227         self.figure.draw(renderer)
#    1228         renderer.finalize()
#    1229
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1409         while len(self.majorTicks) < numticks:
#    1410             # Update the new tick label properties from the old.
# -> 1411             tick = self._get_tick(major=True)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2221         else:
#    2222             tick_kw = self._minor_tick_kw
# -> 2223         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2224
#    2225     def _get_label(self):
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
# --> 160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#     162         self.label2 = self._get_text2()
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/axis.py in _get_gridline(self)
#     609                           alpha=self._grid_alpha,
#     610                           markersize=0,
# --> 611                           **self._grid_kw)
#     612         l.set_transform(self.axes.get_yaxis_transform(which='grid'))
#     613         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     940         self._in_layout = in_layout
#     941
# --> 942     def update(self, props):
#     943         """
#     944         Update this artist's properties from the dictionary *props*.
#
# KeyboardInterrupt:
