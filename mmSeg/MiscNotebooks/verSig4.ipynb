# %% [markdown]
# ## Projection Signature praactice (Row direction, resized images factor=4)

# %%
# Import libraries
import os
import cv2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

rootDir = '../ResizedSS4/'

# Create the directory for the outputs
path = "../Outputs/Plots/verSig4/"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
    
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
        
        file_name = fname.split(".")
        #print('\t%s' % file_name[0])
        
        #reading the file
        image = cv2.imread(dirName + '/' + fname)
        
        #Converting to greyscale
        gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        print(gry.shape)
        sig = np.sum(gry, axis=1)
        print(len(sig))

        plt.plot(sig)
        plt.ylabel('Sum of pixels across columns')
        plt.xlabel('Row')
        plt.title(fname)
        plt.savefig(path + file_name[0] + '.svg')
        plt.show()
# Out:
# Successfully created the directory ../Outputs/Plots/verSig4/
# Found directory: ../ResizedSS4/
# 	RE94_20_0066.jpg
# (1158, 1737)
# 1158
# 	RE94_20_0029.jpg
# (1737, 1158)
# 1737
# 	RE113_21_0094.jpg
# (2172, 1448)
# 2172
# 	RE105_11_0103.jpg
# (1448, 2172)
# 1448
# 	RE105_11_0077.jpg
# (2172, 1448)
# 2172
# 	RE103_7_0033.jpg
# (1448, 2172)
# 1448
# 	RE103_7_0056.jpg
# (1448, 2172)
# 1448
# 	RE113_21_0060.jpg
# (2172, 1448)
# 2172
# 	RE113_21_0095.jpg
# (2172, 1448)
# 2172
# 	RE94_20_0037.jpg
# (1737, 1158)
# 1737
# 	RE113_21_0087.jpg
# (1448, 2172)
# 1448
# 	RE105_6_0052.jpg
# (1448, 2172)
# 1448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2fe308289200> in <module>
#      39         plt.xlabel('Row')
#      40         plt.title(fname)
# ---> 41         plt.savefig(path + file_name[0] + '.svg')
#      42         plt.show()
#
# ...
