# %% [markdown]
# ## Projection Signature praactice (Column direction)

# %%
# Import libraries
import os
import cv2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

rootDir = '../Outputs/edge_images/'

# Create the directory for the outputs
path = "../Outputs/Plots/horsig4/"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
        
        file_name = fname.split(".")
        #print('\t%s' % file_name[0])
        
        #reading the file
        img = cv2.imread(dirName + '/' + fname)
        
        gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        print(gry.shape)
        sig = np.sum(gry, axis=0)
        print(len(sig))
        
        plt.plot(sig)
        plt.ylabel('Sum of pixels across rows')
        plt.xlabel('Column')
        plt.title(fname)
        plt.savefig(path + file_name[0] + '.svg')
        plt.show()
# Out:
# Successfully created the directory ../Outputs/Plots/horsig4/
# Found directory: ../Outputs/edge_images/
# 	RE94_20_0066.jpg
# (1158, 1737)
# 1737
# 	RE94_20_0029.jpg
# (1737, 1158)
# 1158
# 	RE113_21_0094.jpg
# (2172, 1448)
# 1448
# 	RE105_11_0103.jpg
# (1448, 2172)
# 2172
# 	RE105_11_0077.jpg
# (2172, 1448)
# 1448
# 	RE103_7_0033.jpg
# (1448, 2172)
# 2172
# 	RE103_7_0056.jpg
# (1448, 2172)
# 2172
# 	RE113_21_0060.jpg
# (2172, 1448)
# 1448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ed624ba7fd29> in <module>
#      40         plt.title(fname)
#      41         plt.savefig(path + file_name[0] + '.svg')
# ---> 42         plt.show()
#
# ~/anaconda3/envs/sberbank/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ...
